# %%
from detection import*

# %%
imagePath = r"D:\OpenCV\object-detection\test_videos\1.jpg"
videoPath = r"C:\Users\krisn\Downloads\Traffic.webm"

# %%
yolo = YoloV8(segment=False,pose=True)

# %%
#yolo.predictImage(imagePath)
yolo.predictVideo(videoPath=0)
# Out:
# 0: 480x640 1 person, 251.2ms
# Speed: 12.2ms preprocess, 251.2ms inference, 1535.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 151.7ms
# Speed: 4.6ms preprocess, 151.7ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.8ms
# Speed: 4.6ms preprocess, 166.8ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.5ms
# Speed: 2.5ms preprocess, 167.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.2ms
# Speed: 4.7ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.0ms
# Speed: 1.1ms preprocess, 172.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.1ms
# Speed: 4.0ms preprocess, 169.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 148.7ms
# ...

# %%
YTpath = "https://www.youtube.com/live/FIOnLSA246c?si=stFwhkrdiwy5BdY0"

# %%
yolo.predictYouTubeVideo(YTURL=YTpath,skip_frames=5,conf=0.50)
# Out:
# 18:45:46 ::    Helper     :: WARNING  :: GStreamer not found!
# 18:45:46 ::    CamGear    ::   INFO   :: Verifying Streaming URL using yt-dlp backend. Please wait...
# WARNING: [youtube] Skipping player responses from android clients (got player responses for video "aQvGIIdgFDM" instead of "FIOnLSA246c")
# 18:45:49 ::    CamGear    ::   INFO   :: [Backend] :: Streaming URL is fully supported. Available Streams are: [144p, 240p, 360p, 480p, 720p, 1080p, best, worst]
# 18:45:49 ::    CamGear    :: WARNING  :: Livestream URL detected. It is advised to use GStreamer backend(`cv2.CAP_GSTREAMER`) with it.
# 0: 384x640 3 persons, 1 chair, 183.6ms
# Speed: 8.6ms preprocess, 183.6ms inference, 2219.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 135.3ms
# Speed: 4.0ms preprocess, 135.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 133.7ms
# ...
